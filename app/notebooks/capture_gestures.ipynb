# %%
"""
PASO 1: Captura de los 8 gestos
100 muestras por gesto
"""

import cv2
import mediapipe as mp
import numpy as np
import pickle
import os
from collections import deque

# ========== CONFIGURACIÓN ==========
SEQUENCE_LENGTH = 15
DATA_DIR = "../gesture_data"
SAMPLES_PER_GESTURE = 100

os.makedirs(DATA_DIR, exist_ok=True)

# ========== TODOS LOS GESTOS ==========
ALL_GESTURES = [
    "SWIPE_LEFT",
    "SWIPE_RIGHT",
    "SWIPE_UP",
    "SWIPE_DOWN",
    "PINCH_OPEN",
    "PINCH_CLOSE",
    "FIST_CLOSE",
    "OPEN_STATIC"
]

# ========== INSTRUCCIONES ==========
INSTRUCTIONS = {
    "SWIPE_LEFT": [
        "Desliza la mano hacia la IZQUIERDA",
        "Movimiento horizontal claro"
    ],
    "SWIPE_RIGHT": [
        "Desliza la mano hacia la DERECHA",
        "Movimiento horizontal claro"
    ],
    "SWIPE_UP": [
        "Desliza la mano hacia ARRIBA",
        "Movimiento vertical claro"
    ],
    "SWIPE_DOWN": [
        "Desliza la mano hacia ABAJO",
        "Movimiento vertical claro"
    ],
    "PINCH_OPEN": [
        "Empieza: PELLIZCO (indice-pulgar)",
        "Termina: MANO ABIERTA (5 dedos)"
    ],
    "PINCH_CLOSE": [
        "Empieza: MANO ABIERTA (5 dedos)",
        "Termina: PELLIZCO (indice-pulgar)"
    ],
    "FIST_CLOSE": [
        "Empieza: MANO ABIERTA",
        "CIERRA el PUÑO (rapido y claro)"
    ],
    "OPEN_STATIC": [
        "MANO ABIERTA con 5 dedos",
        "QUIETA - No muevas la mano"
    ]
}

# ========== MEDIAPIPE ==========
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

def capture_gesture(gesture_name, num_samples):
    """Capturar muestras de un gesto"""
    
    hands = mp_hands.Hands(
        static_image_mode=False,
        max_num_hands=1,
        min_detection_confidence=0.7,
        min_tracking_confidence=0.7
    )
    
    cap = cv2.VideoCapture(0)
    samples = []
    sequence_buffer = deque(maxlen=SEQUENCE_LENGTH)
    recording = False
    
    print(f"\n{'='*70}")
    print(f"CAPTURANDO: {gesture_name}")
    print(f"{'='*70}")
    print(f"Objetivo: {num_samples} muestras")
    print(f"\nINSTRUCCIONES:")
    for i, inst in enumerate(INSTRUCTIONS[gesture_name], 1):
        print(f"  {i}. {inst}")
    print(f"\n{'='*70}")
    print("ESPACIO = Grabar | Q = Siguiente gesto")
    print(f"{'='*70}\n")
    
    while len(samples) < num_samples:
        ret, frame = cap.read()
        if not ret:
            break
        
        frame = cv2.flip(frame, 1)
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = hands.process(rgb_frame)
        
        height, width = frame.shape[:2]
        
        # Panel superior negro
        overlay = frame.copy()
        cv2.rectangle(overlay, (0, 0), (width, 220), (0, 0, 0), -1)
        cv2.addWeighted(overlay, 0.8, frame, 0.2, 0, frame)
        
        # Título
        cv2.putText(frame, f"GESTO: {gesture_name}", (20, 40),
                   cv2.FONT_HERSHEY_SIMPLEX, 1.2, (0, 255, 255), 3)
        
        # Instrucciones
        y = 80
        for inst in INSTRUCTIONS[gesture_name]:
            cv2.putText(frame, inst, (20, y),
                       cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 1)
            y += 30
        
        # Progreso
        percentage = (len(samples) / num_samples) * 100
        cv2.putText(frame, f"Progreso: {len(samples)}/{num_samples} ({percentage:.0f}%)",
                   (20, 170), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
        
        # Estado
        if recording:
            cv2.putText(frame, "GRABANDO...", (20, 210),
                       cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 0, 255), 3)
            cv2.circle(frame, (width - 50, 50), 20, (0, 0, 255), -1)
        else:
            cv2.putText(frame, "Presiona ESPACIO", (20, 210),
                       cv2.FONT_HERSHEY_SIMPLEX, 0.9, (200, 200, 200), 2)
        
        # Landmarks
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                mp_drawing.draw_landmarks(
                    frame, hand_landmarks, mp_hands.HAND_CONNECTIONS,
                    mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2, circle_radius=3),
                    mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2)
                )
                
                if recording:
                    landmarks = hand_landmarks.landmark
                    landmark_array = np.array([[lm.x, lm.y, lm.z] for lm in landmarks])
                    sequence_buffer.append(landmark_array)
                    
                    # Barra de buffer
                    buffer_progress = len(sequence_buffer)
                    bar_x = width - 420
                    bar_y = height - 50
                    bar_width = 400
                    
                    cv2.rectangle(frame, (bar_x, bar_y), 
                                 (bar_x + bar_width, bar_y + 20), (50, 50, 50), -1)
                    
                    fill = int((buffer_progress / SEQUENCE_LENGTH) * bar_width)
                    cv2.rectangle(frame, (bar_x, bar_y),
                                 (bar_x + fill, bar_y + 20), (0, 255, 255), -1)
                    
                    cv2.putText(frame, f"Buffer: {buffer_progress}/{SEQUENCE_LENGTH}",
                               (bar_x, bar_y - 10),
                               cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 1)
                    
                    if len(sequence_buffer) == SEQUENCE_LENGTH:
                        samples.append(list(sequence_buffer))
                        print(f"✅ Muestra {len(samples)}/{num_samples} ({percentage:.0f}%)")
                        sequence_buffer.clear()
                        recording = False
        else:
            cv2.putText(frame, "NO HAND DETECTED", (20, height - 20),
                       cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        
        cv2.imshow('Captura de Gestos', frame)
        
        key = cv2.waitKey(1) & 0xFF
        if key == ord(' '):
            if not recording and results.multi_hand_landmarks:
                recording = True
                sequence_buffer.clear()
                print(f"🔴 Grabando muestra {len(samples)+1}...")
        elif key == ord('q') or key == ord('Q'):
            break
    
    cap.release()
    hands.close()
    
    # Guardar
    if samples:
        file_path = os.path.join(DATA_DIR, f"{gesture_name}.pkl")
        with open(file_path, 'wb') as f:
            pickle.dump(samples, f)
        print(f"\n✅ {len(samples)} muestras guardadas: {file_path}\n")
    
    return len(samples)

# ========== MAIN ==========
def main():
    print("\n" + "="*70)
    print("CAPTURA DE GESTOS - Sistema Completo")
    print("="*70)
    print(f"\nGestos: {len(ALL_GESTURES)}")
    print(f"Muestras por gesto: {SAMPLES_PER_GESTURE}")
    print(f"Total: {len(ALL_GESTURES) * SAMPLES_PER_GESTURE} muestras\n")
    
    for i, g in enumerate(ALL_GESTURES, 1):
        print(f"{i}. {g}")
    
    print("\n" + "="*70)
    input("Presiona ENTER para comenzar...")
    
    results = {}
    
    for i, gesture in enumerate(ALL_GESTURES, 1):
        print(f"\n{'='*70}")
        print(f"GESTO {i}/{len(ALL_GESTURES)}")
        print(f"{'='*70}")
        
        count = capture_gesture(gesture, SAMPLES_PER_GESTURE)
        results[gesture] = count
        
        if i < len(ALL_GESTURES):
            print(f"\n{'='*70}")
            print(f"Siguiente: {ALL_GESTURES[i]}")
            print("ENTER = Continuar | Q = Salir")
            print(f"{'='*70}\n")
            
            if input().lower() == 'q':
                break
    
    cv2.destroyAllWindows()
    
    # Resumen
    print("\n" + "="*70)
    print("RESUMEN")
    print("="*70)
    total = 0
    for gesture, count in results.items():
        print(f"{gesture}: {count} muestras")
        total += count
    print(f"\nTOTAL: {total} muestras")
    print("="*70)
    print("\n✅ Captura completada!")
    print("Siguiente: Ejecutar 2_train_model.ipynb")

if __name__ == "__main__":
    main()
# Out:
# ======================================================================
# CAPTURA DE GESTOS - Sistema Completo
# ======================================================================
#
# Gestos: 8
# Muestras por gesto: 100
# Total: 800 muestras
#
# 1. SWIPE_LEFT
# 2. SWIPE_RIGHT
# 3. SWIPE_UP
# 4. SWIPE_DOWN
# 5. PINCH_OPEN
# 6. PINCH_CLOSE
# 7. FIST_CLOSE
# 8. OPEN_STATIC
#
# ======================================================================
#
# ======================================================================
# GESTO 1/8
# ======================================================================
#
# ======================================================================
# CAPTURANDO: SWIPE_LEFT
# ======================================================================
# Objetivo: 100 muestras
#
# INSTRUCCIONES:
#   1. Desliza la mano hacia la IZQUIERDA
#   2. Movimiento horizontal claro
#
# ======================================================================
# ESPACIO = Grabar | Q = Siguiente gesto
# ======================================================================
# c:\ELOI\PROGRAMACION\PROYECTOS\LAUZHACK\LAUZHACK\app\venv\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# 🔴 Grabando muestra 1...
# ✅ Muestra 1/100 (0%)
# 🔴 Grabando muestra 2...
# ✅ Muestra 2/100 (1%)
# 🔴 Grabando muestra 3...
# ✅ Muestra 3/100 (2%)
# 🔴 Grabando muestra 4...
# ✅ Muestra 4/100 (3%)
# 🔴 Grabando muestra 5...
# ✅ Muestra 5/100 (4%)
# 🔴 Grabando muestra 6...
# ✅ Muestra 6/100 (5%)
# 🔴 Grabando muestra 7...
# ✅ Muestra 7/100 (6%)
# 🔴 Grabando muestra 8...
# ✅ Muestra 8/100 (7%)
# 🔴 Grabando muestra 9...
# ✅ Muestra 9/100 (8%)
# 🔴 Grabando muestra 10...
# ✅ Muestra 10/100 (9%)
# 🔴 Grabando muestra 11...
# ✅ Muestra 11/100 (10%)
# 🔴 Grabando muestra 12...
# ✅ Muestra 12/100 (11%)
# 🔴 Grabando muestra 13...
# ✅ Muestra 13/100 (12%)
# 🔴 Grabando muestra 14...
# ✅ Muestra 14/100 (13%)
# 🔴 Grabando muestra 15...
# ✅ Muestra 15/100 (14%)
# 🔴 Grabando muestra 16...
# ✅ 100 muestras guardadas: ../gesture_data\SWIPE_LEFT.pkl
#
#
# ======================================================================
# Siguiente: SWIPE_RIGHT
# ENTER = Continuar | Q = Salir
# ======================================================================
#
#
# ======================================================================
# GESTO 2/8
# ======================================================================
#
# ======================================================================
# CAPTURANDO: SWIPE_RIGHT
# ======================================================================
# Objetivo: 100 muestras
#
# INSTRUCCIONES:
#   1. Desliza la mano hacia la DERECHA
#   2. Movimiento horizontal claro
#
# ======================================================================
# ESPACIO = Grabar | Q = Siguiente gesto
# ======================================================================
#
# 🔴 Grabando muestra 1...
# ✅ Muestra 1/100 (0%)
# 🔴 Grabando muestra 2...
# ✅ Muestra 2/100 (1%)
# 🔴 Grabando muestra 3...
# ✅ Muestra 3/100 (2%)
# 🔴 Grabando muestra 4...
# ✅ Muestra 4/100 (3%)
# 🔴 Grabando muestra 5...
# ✅ Muestra 5/100 (4%)
# 🔴 Grabando muestra 6...
# ✅ Muestra 6/100 (5%)
# 🔴 Grabando muestra 7...
# ✅ Muestra 7/100 (6%)
# 🔴 Grabando muestra 8...
# ✅ Muestra 8/100 (7%)
# 🔴 Grabando muestra 9...
# ✅ Muestra 9/100 (8%)
# 🔴 Grabando muestra 10...
# ✅ Muestra 10/100 (9%)
# 🔴 Grabando muestra 11...
# ✅ Muestra 11/100 (10%)
# 🔴 Grabando muestra 12...
# ✅ Muestra 12/100 (11%)
# 🔴 Grabando muestra 13...
# ✅ Muestra 13/100 (12%)
# 🔴 Grabando muestra 14...
# ✅ Muestra 14/100 (13%)
# 🔴 Grabando muestra 15...
# ✅ Muestra 15/100 (14%)
# 🔴 Grabando muestra 16...
# ✅ Muestra 16/100 (15%)
# 🔴 Grabando muestra 17...
# ✅ Muestra 17/100 (16%)
# 🔴 Grabando muestra 18...
# ✅ Muestra 18/100 (17%)
# 🔴 Grabando muestra 19...
# ✅ Muestra 19/100 (18%)
# 🔴 Grabando muestra 20...
# ✅ Muestra 20/100 (19%)
# 🔴 Grabando muestra 21...
# ✅ Muestra 21/100 (20%)
# 🔴 Grabando muestra 22...
# ✅ Muestra 22/100 (21%)
# 🔴 Grabando muestra 23...
# ✅ Muestra 23/100 (22%)
# 🔴 Grabando muestra 24...
# ✅ Muestra 24/100 (23%)
# 🔴 Grabando muestra 25...
# ✅ Muestra 25/100 (24%)
# 🔴 Grabando muestra 26...
# ✅ Muestra 26/100 (25%)
# 🔴 Grabando muestra 27...
# ✅ Muestra 27/100 (26%)
# 🔴 Grabando muestra 28...
# ✅ Muestra 28/100 (27%)
# 🔴 Grabando muestra 29...
# ✅ Muestra 29/100 (28%)
# 🔴 Grabando muestra 30...
# ✅ Muestra 30/100 (29%)
# 🔴 Grabando muestra 31...
# ✅ Muestra 31/100 (30%)
# 🔴 Grabando muestra 32...
# ✅ Muestra 32/100 (31%)
# 🔴 Grabando muestra 33...
# ✅ Muestra 33/100 (32%)
# 🔴 Grabando muestra 34...
# ✅ Muestra 34/100 (33%)
# 🔴 Grabando muestra 35...
# ✅ Muestra 35/100 (34%)
# 🔴 Grabando muestra 78...
# ✅ Muestra 78/100 (77%)
# 🔴 Grabando muestra 79...
# ✅ Muestra 79/100 (78%)
# 🔴 Grabando muestra 80...
# ✅ Muestra 80/100 (79%)
# 🔴 Grabando muestra 81...
# ✅ Muestra 81/100 (80%)
# 🔴 Grabando muestra 82...
# ✅ Muestra 82/100 (81%)
# 🔴 Grabando muestra 83...
# ✅ Muestra 83/100 (82%)
# 🔴 Grabando muestra 84...
# ✅ Muestra 84/100 (83%)
# 🔴 Grabando muestra 85...
# ✅ Muestra 85/100 (84%)
# 🔴 Grabando muestra 86...
# ✅ Muestra 86/100 (85%)
# 🔴 Grabando muestra 87...
# ✅ Muestra 87/100 (86%)
# 🔴 Grabando muestra 88...
# ✅ Muestra 88/100 (87%)
# 🔴 Grabando muestra 89...
# ✅ Muestra 89/100 (88%)
# 🔴 Grabando muestra 90...
# ✅ Muestra 90/100 (89%)
# 🔴 Grabando muestra 91...
# ✅ Muestra 91/100 (90%)
# 🔴 Grabando muestra 92...
# ✅ Muestra 92/100 (91%)
# 🔴 Grabando muestra 93...
# ✅ Muestra 93/100 (92%)
# 🔴 Grabando muestra 94...
# ✅ Muestra 94/100 (93%)
# 🔴 Grabando muestra 95...
# ✅ Muestra 95/100 (94%)
# 🔴 Grabando muestra 96...
# ✅ Muestra 96/100 (95%)
# 🔴 Grabando muestra 97...
# ✅ Muestra 97/100 (96%)
# 🔴 Grabando muestra 98...
# ✅ Muestra 98/100 (97%)
# 🔴 Grabando muestra 99...
# ✅ Muestra 99/100 (98%)
# 🔴 Grabando muestra 100...
# ✅ Muestra 100/100 (99%)
#
# ✅ 100 muestras guardadas: ../gesture_data\SWIPE_RIGHT.pkl
#
#
# ======================================================================
# Siguiente: SWIPE_UP
# ENTER = Continuar | Q = Salir
# ======================================================================
#
#
# ======================================================================
# GESTO 3/8
# ======================================================================
#
# ======================================================================
# CAPTURANDO: SWIPE_UP
# ======================================================================
# Objetivo: 100 muestras
#
# INSTRUCCIONES:
#   1. Desliza la mano hacia ARRIBA
#   2. Movimiento vertical claro
#
# ======================================================================
# ESPACIO = Grabar | Q = Siguiente gesto
# ======================================================================
#
# 🔴 Grabando muestra 1...
# ✅ Muestra 1/100 (0%)
# 🔴 Grabando muestra 2...
# ✅ Muestra 2/100 (1%)
# 🔴 Grabando muestra 3...
# ✅ Muestra 3/100 (2%)
# 🔴 Grabando muestra 4...
# ✅ Muestra 4/100 (3%)
# 🔴 Grabando muestra 5...
# ✅ Muestra 5/100 (4%)
# 🔴 Grabando muestra 6...
# ✅ Muestra 6/100 (5%)
# 🔴 Grabando muestra 7...
# ✅ Muestra 7/100 (6%)
# 🔴 Grabando muestra 8...
# ✅ Muestra 8/100 (7%)
# 🔴 Grabando muestra 9...
# ✅ Muestra 9/100 (8%)
# 🔴 Grabando muestra 10...
# ✅ Muestra 10/100 (9%)
# 🔴 Grabando muestra 11...
# ✅ Muestra 11/100 (10%)
# 🔴 Grabando muestra 12...
# ✅ Muestra 12/100 (11%)
# ✅ Muestra 97/100 (96%)
# 🔴 Grabando muestra 98...
# ✅ Muestra 98/100 (97%)
# 🔴 Grabando muestra 99...
# ✅ Muestra 99/100 (98%)
# 🔴 Grabando muestra 100...
# ✅ Muestra 100/100 (99%)
#
# ✅ 100 muestras guardadas: ../gesture_data\SWIPE_UP.pkl
#
#
# ======================================================================
# Siguiente: SWIPE_DOWN
# ENTER = Continuar | Q = Salir
# ======================================================================
#
#
# ======================================================================
# GESTO 4/8
# ======================================================================
#
# ======================================================================
# CAPTURANDO: SWIPE_DOWN
# ======================================================================
# Objetivo: 100 muestras
#
# INSTRUCCIONES:
#   1. Desliza la mano hacia ABAJO
#   2. Movimiento vertical claro
#
# ======================================================================
# ESPACIO = Grabar | Q = Siguiente gesto
# ======================================================================
#
# 🔴 Grabando muestra 1...
# ✅ Muestra 1/100 (0%)
# 🔴 Grabando muestra 2...
# ✅ Muestra 2/100 (1%)
# 🔴 Grabando muestra 3...
# ✅ Muestra 3/100 (2%)
# 🔴 Grabando muestra 4...
# ✅ Muestra 4/100 (3%)
# 🔴 Grabando muestra 5...
# ✅ Muestra 5/100 (4%)
# 🔴 Grabando muestra 6...
# ✅ Muestra 6/100 (5%)
# 🔴 Grabando muestra 7...
# ✅ Muestra 7/100 (6%)
# 🔴 Grabando muestra 8...
# ✅ Muestra 8/100 (7%)
# 🔴 Grabando muestra 9...
# ✅ Muestra 9/100 (8%)
# 🔴 Grabando muestra 10...
# ✅ Muestra 10/100 (9%)
# 🔴 Grabando muestra 11...
# ✅ Muestra 11/100 (10%)
# 🔴 Grabando muestra 12...
# ✅ Muestra 12/100 (11%)
# 🔴 Grabando muestra 13...
# ✅ Muestra 13/100 (12%)
# 🔴 Grabando muestra 14...
# ✅ Muestra 14/100 (13%)
# 🔴 Grabando muestra 15...
# ✅ Muestra 15/100 (14%)
# 🔴 Grabando muestra 16...
# ✅ Muestra 16/100 (15%)
# 🔴 Grabando muestra 17...
# ✅ Muestra 17/100 (16%)
# 🔴 Grabando muestra 18...
# ✅ Muestra 18/100 (17%)
# 🔴 Grabando muestra 19...
# ✅ Muestra 19/100 (18%)
# 🔴 Grabando muestra 20...
# ✅ Muestra 20/100 (19%)
# 🔴 Grabando muestra 21...
# ✅ Muestra 21/100 (20%)
# 🔴 Grabando muestra 22...
# ✅ Muestra 22/100 (21%)
# 🔴 Grabando muestra 23...
# ✅ Muestra 23/100 (22%)
# 🔴 Grabando muestra 24...
# ✅ Muestra 24/100 (23%)
# 🔴 Grabando muestra 25...
# ✅ Muestra 25/100 (24%)
# 🔴 Grabando muestra 26...
# ✅ Muestra 26/100 (25%)
# 🔴 Grabando muestra 27...
# ✅ Muestra 27/100 (26%)
# 🔴 Grabando muestra 28...
# ✅ Muestra 28/100 (27%)
# 🔴 Grabando muestra 29...
# ✅ Muestra 29/100 (28%)
# 🔴 Grabando muestra 30...
# ✅ Muestra 30/100 (29%)
# 🔴 Grabando muestra 31...
# ✅ Muestra 31/100 (30%)
# 🔴 Grabando muestra 32...
# ✅ Muestra 74/100 (73%)
# 🔴 Grabando muestra 75...
# ✅ Muestra 75/100 (74%)
# 🔴 Grabando muestra 76...
# ✅ Muestra 76/100 (75%)
# 🔴 Grabando muestra 77...
# ✅ Muestra 77/100 (76%)
# 🔴 Grabando muestra 78...
# ✅ Muestra 78/100 (77%)
# 🔴 Grabando muestra 79...
# ✅ Muestra 79/100 (78%)
# 🔴 Grabando muestra 80...
# ✅ Muestra 80/100 (79%)
# 🔴 Grabando muestra 81...
# ✅ Muestra 81/100 (80%)
# 🔴 Grabando muestra 82...
# ✅ Muestra 82/100 (81%)
# 🔴 Grabando muestra 83...
# ✅ Muestra 83/100 (82%)
# 🔴 Grabando muestra 84...
# ✅ Muestra 84/100 (83%)
# 🔴 Grabando muestra 85...
# ✅ Muestra 85/100 (84%)
# 🔴 Grabando muestra 86...
# ✅ Muestra 86/100 (85%)
# 🔴 Grabando muestra 87...
# ✅ Muestra 87/100 (86%)
# 🔴 Grabando muestra 88...
# ✅ Muestra 88/100 (87%)
# 🔴 Grabando muestra 89...
# ✅ Muestra 89/100 (88%)
# 🔴 Grabando muestra 90...
# ✅ Muestra 90/100 (89%)
# 🔴 Grabando muestra 91...
# ✅ Muestra 91/100 (90%)
# 🔴 Grabando muestra 92...
# ✅ Muestra 92/100 (91%)
# 🔴 Grabando muestra 93...
# ✅ Muestra 93/100 (92%)
# 🔴 Grabando muestra 94...
# ✅ Muestra 94/100 (93%)
# 🔴 Grabando muestra 95...
# ✅ Muestra 95/100 (94%)
# 🔴 Grabando muestra 96...
# ✅ Muestra 96/100 (95%)
# 🔴 Grabando muestra 97...
# ✅ Muestra 97/100 (96%)
# 🔴 Grabando muestra 98...
# ✅ Muestra 98/100 (97%)
# 🔴 Grabando muestra 99...
# ✅ Muestra 99/100 (98%)
# 🔴 Grabando muestra 100...
# ✅ Muestra 100/100 (99%)
#
# ✅ 100 muestras guardadas: ../gesture_data\SWIPE_DOWN.pkl
#
#
# ======================================================================
# Siguiente: PINCH_OPEN
# ENTER = Continuar | Q = Salir
# ======================================================================
#
#
# ======================================================================
# GESTO 5/8
# ======================================================================
#
# ======================================================================
# CAPTURANDO: PINCH_OPEN
# ======================================================================
# Objetivo: 100 muestras
#
# INSTRUCCIONES:
#   1. Empieza: PELLIZCO (indice-pulgar)
#   2. Termina: MANO ABIERTA (5 dedos)
#
# ======================================================================
# ESPACIO = Grabar | Q = Siguiente gesto
# ======================================================================
#
# 🔴 Grabando muestra 1...
# ✅ Muestra 1/100 (0%)
# 🔴 Grabando muestra 2...
# ✅ Muestra 2/100 (1%)
# 🔴 Grabando muestra 3...
# ✅ Muestra 3/100 (2%)
# 🔴 Grabando muestra 4...
# ✅ Muestra 4/100 (3%)
# 🔴 Grabando muestra 5...
# ✅ Muestra 5/100 (4%)
# 🔴 Grabando muestra 6...
# ✅ Muestra 6/100 (5%)
# 🔴 Grabando muestra 7...
# ✅ Muestra 7/100 (6%)
# 🔴 Grabando muestra 8...
# ✅ Muestra 8/100 (7%)
# 🔴 Grabando muestra 9...
# ✅ Muestra 9/100 (8%)
# 🔴 Grabando muestra 10...
# ✅ Muestra 10/100 (9%)
# 🔴 Grabando muestra 11...
# ✅ Muestra 11/100 (10%)
# 🔴 Grabando muestra 12...
# ✅ Muestra 12/100 (11%)
# 🔴 Grabando muestra 13...
# ✅ Muestra 13/100 (12%)
# 🔴 Grabando muestra 14...
# ✅ Muestra 14/100 (13%)
# 🔴 Grabando muestra 15...
# ✅ Muestra 15/100 (14%)
# 🔴 Grabando muestra 16...
# ✅ Muestra 16/100 (15%)
# 🔴 Grabando muestra 17...
# ✅ Muestra 17/100 (16%)
# 🔴 Grabando muestra 18...
# ✅ Muestra 18/100 (17%)
# 🔴 Grabando muestra 19...
# ✅ Muestra 19/100 (18%)
# 🔴 Grabando muestra 20...
# ✅ Muestra 20/100 (19%)
# 🔴 Grabando muestra 21...
# ✅ Muestra 21/100 (20%)
# 🔴 Grabando muestra 22...
# ✅ Muestra 22/100 (21%)
# 🔴 Grabando muestra 23...
# ✅ Muestra 23/100 (22%)
# 🔴 Grabando muestra 24...
# ✅ Muestra 24/100 (23%)
# 🔴 Grabando muestra 25...
# ✅ Muestra 25/100 (24%)
# 🔴 Grabando muestra 26...
# ✅ Muestra 26/100 (25%)
# 🔴 Grabando muestra 27...
# ✅ Muestra 27/100 (26%)
# 🔴 Grabando muestra 28...
# ✅ Muestra 28/100 (27%)
# 🔴 Grabando muestra 29...
# ✅ Muestra 29/100 (28%)
# 🔴 Grabando muestra 30...
# ✅ Muestra 30/100 (29%)
# 🔴 Grabando muestra 31...
# ✅ Muestra 31/100 (30%)
# 🔴 Grabando muestra 32...
# ✅ Muestra 32/100 (31%)
# 🔴 Grabando muestra 33...
# ✅ Muestra 33/100 (32%)
# 🔴 Grabando muestra 34...
# ✅ Muestra 34/100 (33%)
# 🔴 Grabando muestra 35...
# ✅ Muestra 35/100 (34%)
# 🔴 Grabando muestra 36...
# ✅ Muestra 36/100 (35%)
# 🔴 Grabando muestra 37...
# ✅ Muestra 37/100 (36%)
# 🔴 Grabando muestra 38...
# ✅ Muestra 38/100 (37%)
# 🔴 Grabando muestra 39...
# ✅ Muestra 39/100 (38%)
# 🔴 Grabando muestra 40...
# ✅ Muestra 40/100 (39%)
# 🔴 Grabando muestra 41...
# ✅ Muestra 41/100 (40%)
# 🔴 Grabando muestra 42...
# ✅ Muestra 42/100 (41%)
# 🔴 Grabando muestra 43...
# ✅ Muestra 43/100 (42%)
# 🔴 Grabando muestra 44...
# ✅ Muestra 44/100 (43%)
# 🔴 Grabando muestra 45...
# ✅ Muestra 45/100 (44%)
# 🔴 Grabando muestra 46...
# ✅ Muestra 46/100 (45%)
# 🔴 Grabando muestra 47...
# ✅ Muestra 47/100 (46%)
# 🔴 Grabando muestra 48...
# ✅ Muestra 48/100 (47%)
# 🔴 Grabando muestra 49...
# ✅ Muestra 49/100 (48%)
# 🔴 Grabando muestra 50...
# ✅ Muestra 50/100 (49%)
# 🔴 Grabando muestra 51...
# ✅ Muestra 93/100 (92%)
# 🔴 Grabando muestra 94...
# ✅ Muestra 94/100 (93%)
# 🔴 Grabando muestra 95...
# ✅ Muestra 95/100 (94%)
# 🔴 Grabando muestra 96...
# ✅ Muestra 96/100 (95%)
# 🔴 Grabando muestra 97...
# ✅ Muestra 97/100 (96%)
# 🔴 Grabando muestra 98...
# ✅ Muestra 98/100 (97%)
# 🔴 Grabando muestra 99...
# ✅ Muestra 99/100 (98%)
# 🔴 Grabando muestra 100...
# ✅ Muestra 100/100 (99%)
#
# ✅ 100 muestras guardadas: ../gesture_data\PINCH_OPEN.pkl
#
#
# ======================================================================
# Siguiente: PINCH_CLOSE
# ENTER = Continuar | Q = Salir
# ======================================================================
#
#
# ======================================================================
# GESTO 6/8
# ======================================================================
#
# ======================================================================
# CAPTURANDO: PINCH_CLOSE
# ======================================================================
# Objetivo: 100 muestras
#
# INSTRUCCIONES:
#   1. Empieza: MANO ABIERTA (5 dedos)
#   2. Termina: PELLIZCO (indice-pulgar)
#
# ======================================================================
# ESPACIO = Grabar | Q = Siguiente gesto
# ======================================================================
#
# 🔴 Grabando muestra 1...
# ✅ Muestra 1/100 (0%)
# 🔴 Grabando muestra 2...
# ✅ Muestra 2/100 (1%)
# 🔴 Grabando muestra 3...
# ✅ Muestra 3/100 (2%)
# 🔴 Grabando muestra 4...
# ✅ Muestra 4/100 (3%)
# 🔴 Grabando muestra 5...
# ✅ Muestra 5/100 (4%)
# 🔴 Grabando muestra 6...
# ✅ Muestra 6/100 (5%)
# 🔴 Grabando muestra 7...
# ✅ Muestra 7/100 (6%)
# 🔴 Grabando muestra 8...
# ✅ Muestra 8/100 (7%)
# 🔴 Grabando muestra 9...
# ✅ Muestra 9/100 (8%)
# 🔴 Grabando muestra 10...
# ✅ Muestra 10/100 (9%)
# 🔴 Grabando muestra 11...
# ✅ Muestra 11/100 (10%)
# 🔴 Grabando muestra 12...
# ✅ Muestra 12/100 (11%)
# 🔴 Grabando muestra 13...
# ✅ Muestra 13/100 (12%)
# 🔴 Grabando muestra 14...
# ✅ Muestra 14/100 (13%)
# 🔴 Grabando muestra 15...
# ✅ Muestra 15/100 (14%)
# 🔴 Grabando muestra 16...
# ✅ Muestra 16/100 (15%)
# 🔴 Grabando muestra 17...
# ✅ Muestra 17/100 (16%)
# 🔴 Grabando muestra 18...
# ✅ Muestra 18/100 (17%)
# 🔴 Grabando muestra 19...
# ✅ Muestra 19/100 (18%)
# 🔴 Grabando muestra 20...
# ✅ Muestra 20/100 (19%)
# 🔴 Grabando muestra 21...
# ✅ Muestra 21/100 (20%)
# 🔴 Grabando muestra 22...
# ✅ Muestra 22/100 (21%)
# 🔴 Grabando muestra 23...
# ✅ Muestra 23/100 (22%)
# 🔴 Grabando muestra 24...
# ✅ Muestra 24/100 (23%)
# 🔴 Grabando muestra 25...
# ✅ Muestra 25/100 (24%)
# 🔴 Grabando muestra 26...
# ✅ Muestra 26/100 (25%)
# 🔴 Grabando muestra 27...
# ✅ Muestra 27/100 (26%)
# ✅ Muestra 70/100 (69%)
# 🔴 Grabando muestra 71...
# ✅ Muestra 71/100 (70%)
# 🔴 Grabando muestra 72...
# ✅ Muestra 72/100 (71%)
# 🔴 Grabando muestra 73...
# ✅ Muestra 73/100 (72%)
# 🔴 Grabando muestra 74...
# ✅ Muestra 74/100 (73%)
# 🔴 Grabando muestra 75...
# ✅ Muestra 75/100 (74%)
# 🔴 Grabando muestra 76...
# ✅ Muestra 76/100 (75%)
# 🔴 Grabando muestra 77...
# ✅ Muestra 77/100 (76%)
# 🔴 Grabando muestra 78...
# ✅ Muestra 78/100 (77%)
# 🔴 Grabando muestra 79...
# ✅ Muestra 79/100 (78%)
# 🔴 Grabando muestra 80...
# ✅ Muestra 80/100 (79%)
# 🔴 Grabando muestra 81...
# ✅ Muestra 81/100 (80%)
# 🔴 Grabando muestra 82...
# ✅ Muestra 82/100 (81%)
# 🔴 Grabando muestra 83...
# ✅ Muestra 83/100 (82%)
# 🔴 Grabando muestra 84...
# ✅ Muestra 84/100 (83%)
# 🔴 Grabando muestra 85...
# ✅ Muestra 85/100 (84%)
# 🔴 Grabando muestra 86...
# ✅ Muestra 86/100 (85%)
# 🔴 Grabando muestra 87...
# ✅ Muestra 87/100 (86%)
# 🔴 Grabando muestra 88...
# ✅ Muestra 88/100 (87%)
# 🔴 Grabando muestra 89...
# ✅ Muestra 89/100 (88%)
# 🔴 Grabando muestra 90...
# ✅ Muestra 90/100 (89%)
# 🔴 Grabando muestra 91...
# ✅ Muestra 91/100 (90%)
# 🔴 Grabando muestra 92...
# ✅ Muestra 92/100 (91%)
# 🔴 Grabando muestra 93...
# ✅ Muestra 93/100 (92%)
# 🔴 Grabando muestra 94...
# ✅ Muestra 94/100 (93%)
# 🔴 Grabando muestra 95...
# ✅ Muestra 95/100 (94%)
# 🔴 Grabando muestra 96...
# ✅ Muestra 96/100 (95%)
# 🔴 Grabando muestra 97...
# ✅ Muestra 97/100 (96%)
# 🔴 Grabando muestra 98...
# ✅ Muestra 98/100 (97%)
# 🔴 Grabando muestra 99...
# ✅ Muestra 99/100 (98%)
# 🔴 Grabando muestra 100...
# ✅ Muestra 100/100 (99%)
#
# ✅ 100 muestras guardadas: ../gesture_data\PINCH_CLOSE.pkl
#
#
# ======================================================================
# Siguiente: FIST_CLOSE
# ENTER = Continuar | Q = Salir
# ======================================================================
#
#
# ======================================================================
# GESTO 7/8
# ======================================================================
#
# ======================================================================
# CAPTURANDO: FIST_CLOSE
# ======================================================================
# Objetivo: 100 muestras
#
# INSTRUCCIONES:
#   1. Empieza: MANO ABIERTA
#   2. CIERRA el PUÑO (rapido y claro)
#
# ======================================================================
# ESPACIO = Grabar | Q = Siguiente gesto
# ======================================================================
#
# 🔴 Grabando muestra 1...
# ✅ Muestra 1/100 (0%)
# 🔴 Grabando muestra 2...
# ✅ Muestra 2/100 (1%)
# 🔴 Grabando muestra 3...
# ✅ Muestra 3/100 (2%)
# 🔴 Grabando muestra 4...
# ✅ Muestra 4/100 (3%)
# 🔴 Grabando muestra 5...
# ✅ Muestra 5/100 (4%)
# 🔴 Grabando muestra 6...
# ✅ Muestra 6/100 (5%)
# 🔴 Grabando muestra 7...
# ✅ Muestra 7/100 (6%)
# 🔴 Grabando muestra 8...
# ✅ Muestra 8/100 (7%)
# 🔴 Grabando muestra 9...
# ✅ Muestra 9/100 (8%)
# 🔴 Grabando muestra 10...
# ✅ Muestra 10/100 (9%)
# 🔴 Grabando muestra 11...
# ✅ Muestra 11/100 (10%)
# 🔴 Grabando muestra 12...
# ✅ Muestra 12/100 (11%)
# 🔴 Grabando muestra 13...
# ✅ Muestra 13/100 (12%)
# 🔴 Grabando muestra 14...
# ✅ Muestra 14/100 (13%)
# 🔴 Grabando muestra 15...
# ✅ Muestra 15/100 (14%)
# 🔴 Grabando muestra 16...
# ✅ Muestra 16/100 (15%)
# 🔴 Grabando muestra 17...
# ✅ Muestra 17/100 (16%)
# 🔴 Grabando muestra 18...
# ✅ Muestra 18/100 (17%)
# 🔴 Grabando muestra 19...
# ✅ Muestra 19/100 (18%)
# 🔴 Grabando muestra 20...
# ✅ Muestra 20/100 (19%)
# 🔴 Grabando muestra 21...
# ✅ Muestra 21/100 (20%)
# 🔴 Grabando muestra 22...
# ✅ Muestra 22/100 (21%)
# 🔴 Grabando muestra 23...
# ✅ Muestra 23/100 (22%)
# 🔴 Grabando muestra 24...
# ✅ Muestra 24/100 (23%)
# 🔴 Grabando muestra 25...
# ✅ Muestra 25/100 (24%)
# 🔴 Grabando muestra 26...
# ✅ Muestra 26/100 (25%)
# 🔴 Grabando muestra 27...
# ✅ Muestra 27/100 (26%)
# 🔴 Grabando muestra 28...
# ✅ Muestra 28/100 (27%)
# 🔴 Grabando muestra 29...
# ✅ Muestra 29/100 (28%)
# 🔴 Grabando muestra 30...
# ✅ Muestra 30/100 (29%)
# 🔴 Grabando muestra 31...
# ✅ Muestra 31/100 (30%)
# 🔴 Grabando muestra 32...
# ✅ Muestra 32/100 (31%)
# 🔴 Grabando muestra 33...
# ✅ Muestra 33/100 (32%)
# 🔴 Grabando muestra 34...
# ✅ Muestra 34/100 (33%)
# 🔴 Grabando muestra 35...
# ✅ Muestra 35/100 (34%)
# 🔴 Grabando muestra 36...
# ✅ Muestra 36/100 (35%)
# 🔴 Grabando muestra 37...
# ✅ Muestra 37/100 (36%)
# 🔴 Grabando muestra 38...
# ✅ Muestra 38/100 (37%)
# 🔴 Grabando muestra 39...
# ✅ Muestra 39/100 (38%)
# 🔴 Grabando muestra 40...
# ✅ Muestra 40/100 (39%)
# 🔴 Grabando muestra 41...
# ✅ Muestra 41/100 (40%)
# 🔴 Grabando muestra 42...
# ✅ Muestra 42/100 (41%)
# 🔴 Grabando muestra 43...
# ✅ Muestra 43/100 (42%)
# 🔴 Grabando muestra 44...
# ✅ Muestra 44/100 (43%)
# 🔴 Grabando muestra 45...
# ✅ Muestra 45/100 (44%)
# 🔴 Grabando muestra 46...
# ✅ Muestra 46/100 (45%)
# ✅ Muestra 89/100 (88%)
# 🔴 Grabando muestra 90...
# ✅ Muestra 90/100 (89%)
# 🔴 Grabando muestra 91...
# ✅ Muestra 91/100 (90%)
# 🔴 Grabando muestra 92...
# ✅ Muestra 92/100 (91%)
# 🔴 Grabando muestra 93...
# ✅ Muestra 93/100 (92%)
# 🔴 Grabando muestra 94...
# ✅ Muestra 94/100 (93%)
# 🔴 Grabando muestra 95...
# ✅ Muestra 95/100 (94%)
# 🔴 Grabando muestra 96...
# ✅ Muestra 96/100 (95%)
# 🔴 Grabando muestra 97...
# ✅ Muestra 97/100 (96%)
# 🔴 Grabando muestra 98...
# ✅ Muestra 98/100 (97%)
# 🔴 Grabando muestra 99...
# ✅ Muestra 99/100 (98%)
# 🔴 Grabando muestra 100...
# ✅ Muestra 100/100 (99%)
#
# ✅ 100 muestras guardadas: ../gesture_data\FIST_CLOSE.pkl
#
#
# ======================================================================
# Siguiente: OPEN_STATIC
# ENTER = Continuar | Q = Salir
# ======================================================================
#
#
# ======================================================================
# GESTO 8/8
# ======================================================================
#
# ======================================================================
# CAPTURANDO: OPEN_STATIC
# ======================================================================
# Objetivo: 100 muestras
#
# INSTRUCCIONES:
#   1. MANO ABIERTA con 5 dedos
#   2. QUIETA - No muevas la mano
#
# ======================================================================
# ESPACIO = Grabar | Q = Siguiente gesto
# ======================================================================
#
# 🔴 Grabando muestra 1...
# ✅ Muestra 1/100 (0%)
# 🔴 Grabando muestra 2...
# ✅ Muestra 2/100 (1%)
# 🔴 Grabando muestra 3...
# ✅ Muestra 3/100 (2%)
# 🔴 Grabando muestra 4...
# ✅ Muestra 4/100 (3%)
# 🔴 Grabando muestra 5...
# ✅ Muestra 5/100 (4%)
# 🔴 Grabando muestra 6...
# ✅ Muestra 6/100 (5%)
# 🔴 Grabando muestra 7...
# ✅ Muestra 7/100 (6%)
# 🔴 Grabando muestra 8...
# ✅ Muestra 8/100 (7%)
# 🔴 Grabando muestra 9...
# ✅ Muestra 9/100 (8%)
# 🔴 Grabando muestra 10...
# ✅ Muestra 10/100 (9%)
# 🔴 Grabando muestra 11...
# ✅ Muestra 11/100 (10%)
# 🔴 Grabando muestra 12...
# ✅ Muestra 12/100 (11%)
# 🔴 Grabando muestra 13...
# ✅ Muestra 13/100 (12%)
# 🔴 Grabando muestra 14...
# ✅ Muestra 14/100 (13%)
# 🔴 Grabando muestra 15...
# ✅ Muestra 15/100 (14%)
# 🔴 Grabando muestra 16...
# ✅ Muestra 16/100 (15%)
# 🔴 Grabando muestra 17...
# ✅ Muestra 17/100 (16%)
# 🔴 Grabando muestra 18...
# ✅ Muestra 18/100 (17%)
# 🔴 Grabando muestra 19...
# ✅ Muestra 19/100 (18%)
# 🔴 Grabando muestra 20...
# ✅ Muestra 20/100 (19%)
# 🔴 Grabando muestra 21...
# ✅ Muestra 21/100 (20%)
# 🔴 Grabando muestra 22...
# ✅ Muestra 22/100 (21%)
# 🔴 Grabando muestra 23...
# ✅ Muestra 23/100 (22%)
# 🔴 Grabando muestra 24...
# ✅ Muestra 24/100 (23%)
# 🔴 Grabando muestra 25...
# ✅ Muestra 25/100 (24%)
# 🔴 Grabando muestra 26...
# ✅ Muestra 26/100 (25%)
# 🔴 Grabando muestra 27...
# ✅ Muestra 27/100 (26%)
# 🔴 Grabando muestra 28...
# ✅ Muestra 28/100 (27%)
# 🔴 Grabando muestra 29...
# ✅ Muestra 29/100 (28%)
# 🔴 Grabando muestra 30...
# ✅ Muestra 30/100 (29%)
# 🔴 Grabando muestra 31...
# ✅ Muestra 31/100 (30%)
# 🔴 Grabando muestra 32...
# ✅ Muestra 32/100 (31%)
# 🔴 Grabando muestra 33...
# ✅ Muestra 33/100 (32%)
# 🔴 Grabando muestra 34...
# ✅ Muestra 34/100 (33%)
# 🔴 Grabando muestra 35...
# ✅ Muestra 35/100 (34%)
# 🔴 Grabando muestra 36...
# ✅ Muestra 36/100 (35%)
# 🔴 Grabando muestra 37...
# ✅ Muestra 37/100 (36%)
# 🔴 Grabando muestra 38...
# ✅ Muestra 38/100 (37%)
# 🔴 Grabando muestra 39...
# ✅ Muestra 39/100 (38%)
# 🔴 Grabando muestra 40...
# ✅ Muestra 40/100 (39%)
# 🔴 Grabando muestra 41...
# ✅ Muestra 41/100 (40%)
# 🔴 Grabando muestra 42...
# ✅ Muestra 42/100 (41%)
# 🔴 Grabando muestra 43...
# ✅ Muestra 43/100 (42%)
# 🔴 Grabando muestra 44...
# ✅ Muestra 44/100 (43%)
# 🔴 Grabando muestra 45...
# ✅ Muestra 45/100 (44%)
# 🔴 Grabando muestra 46...
# ✅ Muestra 46/100 (45%)
# 🔴 Grabando muestra 47...
# ✅ Muestra 47/100 (46%)
# 🔴 Grabando muestra 48...
# ✅ Muestra 48/100 (47%)
# 🔴 Grabando muestra 49...
# ✅ Muestra 49/100 (48%)
# 🔴 Grabando muestra 50...
# ✅ Muestra 50/100 (49%)
# 🔴 Grabando muestra 51...
# ✅ Muestra 51/100 (50%)
# 🔴 Grabando muestra 52...
# ✅ Muestra 52/100 (51%)
# 🔴 Grabando muestra 53...
# ✅ Muestra 53/100 (52%)
# 🔴 Grabando muestra 54...
# ✅ Muestra 54/100 (53%)
# 🔴 Grabando muestra 55...
# ✅ Muestra 55/100 (54%)
# 🔴 Grabando muestra 56...
# ✅ Muestra 56/100 (55%)
# 🔴 Grabando muestra 57...
# ✅ Muestra 57/100 (56%)
# 🔴 Grabando muestra 58...
# ✅ Muestra 58/100 (57%)
# 🔴 Grabando muestra 59...
# ✅ Muestra 59/100 (58%)
# 🔴 Grabando muestra 60...
# ✅ Muestra 60/100 (59%)
# 🔴 Grabando muestra 61...
# ✅ Muestra 61/100 (60%)
# 🔴 Grabando muestra 62...
# ✅ Muestra 62/100 (61%)
# 🔴 Grabando muestra 63...
# ✅ Muestra 63/100 (62%)
# 🔴 Grabando muestra 64...
# ✅ Muestra 64/100 (63%)
# 🔴 Grabando muestra 65...
# ✅ Muestra 65/100 (64%)
# 🔴 Grabando muestra 66...
# ✅ Muestra 66/100 (65%)
# 🔴 Grabando muestra 67...
# ✅ Muestra 67/100 (66%)
# 🔴 Grabando muestra 68...
# ✅ Muestra 68/100 (67%)
# 🔴 Grabando muestra 69...
# ✅ Muestra 69/100 (68%)
# 🔴 Grabando muestra 70...
# ✅ Muestra 70/100 (69%)
# 🔴 Grabando muestra 71...
# ✅ Muestra 71/100 (70%)
# 🔴 Grabando muestra 72...
# ✅ Muestra 72/100 (71%)
# 🔴 Grabando muestra 73...
# ✅ Muestra 73/100 (72%)
# 🔴 Grabando muestra 74...
# ✅ Muestra 74/100 (73%)
# 🔴 Grabando muestra 75...
# ✅ Muestra 75/100 (74%)
# 🔴 Grabando muestra 76...
# ✅ Muestra 76/100 (75%)
# 🔴 Grabando muestra 77...
# ✅ Muestra 77/100 (76%)
# 🔴 Grabando muestra 78...
# ✅ Muestra 78/100 (77%)
# 🔴 Grabando muestra 79...
# ✅ Muestra 79/100 (78%)
# 🔴 Grabando muestra 80...
# ✅ Muestra 80/100 (79%)
# 🔴 Grabando muestra 81...
# ✅ Muestra 81/100 (80%)
# 🔴 Grabando muestra 82...
# ✅ Muestra 82/100 (81%)
# 🔴 Grabando muestra 83...
# ✅ Muestra 83/100 (82%)
# 🔴 Grabando muestra 84...
# ✅ Muestra 84/100 (83%)
# 🔴 Grabando muestra 85...
# ✅ Muestra 85/100 (84%)
# 🔴 Grabando muestra 86...
# ✅ Muestra 86/100 (85%)
# 🔴 Grabando muestra 87...
# ✅ Muestra 87/100 (86%)
# 🔴 Grabando muestra 88...
# ✅ Muestra 88/100 (87%)
# 🔴 Grabando muestra 89...
# ✅ Muestra 89/100 (88%)
# 🔴 Grabando muestra 90...
# ✅ Muestra 90/100 (89%)
# 🔴 Grabando muestra 91...
# ✅ Muestra 91/100 (90%)
# 🔴 Grabando muestra 92...
# ✅ Muestra 92/100 (91%)
# 🔴 Grabando muestra 93...
# ✅ Muestra 93/100 (92%)
# 🔴 Grabando muestra 94...
# ✅ Muestra 94/100 (93%)
# 🔴 Grabando muestra 95...
# ✅ Muestra 95/100 (94%)
# 🔴 Grabando muestra 96...
# ✅ Muestra 96/100 (95%)
# 🔴 Grabando muestra 97...
# ✅ Muestra 97/100 (96%)
# 🔴 Grabando muestra 98...
# ✅ Muestra 98/100 (97%)
# 🔴 Grabando muestra 99...
# ✅ Muestra 99/100 (98%)
# 🔴 Grabando muestra 100...
# ✅ Muestra 100/100 (99%)
#
# ✅ 100 muestras guardadas: ../gesture_data\OPEN_STATIC.pkl
#
#
# ======================================================================
# RESUMEN
# ======================================================================
# SWIPE_LEFT: 100 muestras
# SWIPE_RIGHT: 100 muestras
# SWIPE_UP: 100 muestras
# SWIPE_DOWN: 100 muestras
# PINCH_OPEN: 100 muestras
# PINCH_CLOSE: 100 muestras
# FIST_CLOSE: 100 muestras
# OPEN_STATIC: 100 muestras
#
# TOTAL: 800 muestras
# ======================================================================
#
# ✅ Captura completada!
# Siguiente: Ejecutar 2_train_model.ipynb
